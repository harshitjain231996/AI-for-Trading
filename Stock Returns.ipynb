# %% [markdown]
# # Raw Return
# 1. Using returns ensure that the price is normalized and are similar in scale.
# 2. Percentage Returns = (current price - previous price)/(previous price). Example - a. We bought a stock at 1000 and sold a stock at 1050 later. So the return is = (1050-1000)/1000 = 50/1000 = 0.05 i.e. 5 percent. b. Another stock was bought at 5000 and sold at 5300 later. So the return on this stock is (5300-5000)/5000 = 300/5000 = 0.06 i.e. 6 percent.
# 3. Instead of comparing 300 with 50 we can compare the returns of the stocks and then get the result accordingly. So prices are normalized and are similar in scale when we use returns.

# %% [markdown]
# # Log Return
# 1. log return = ln(current price/previous price)
# 2. log return = ln(raw return + 1)
# 3. Special case : When raw return <<1 the graph behaves like this:
#
# ![natural%20log%20and%20raw%20log%20special%20case%20graphically.PNG](attachment:natural%20log%20and%20raw%20log%20special%20case%20graphically.PNG)

# %% [markdown]
# 1. Investors are always interested in the potential appreciation or depreciation of financial assets. They'd like to be able to predict what will happen to assets in the future, hence, they'd like to be able to build models of stock prices and returns. An important first step is to think of these prices and returns as random variables, i.e. outcomes of random phenomena, that take on values as described by distributions. Distributions allow us to summarize the behavior of random variables. To get a sense of potential future behaviour, we look at the past.
# 2. Central Limit Theorem - The sum of random variables that have the same distribution and are not dependent on each other approaches a normal distribution in the limit the number of random variables goes to infinity.
#
# ![central%20limit%20theorem.PNG](attachment:central%20limit%20theorem.PNG)
#
# 3. If y is normally distributed then e^y is log normally distributed. For example, if log(p) is normally distributed, then e^log(p) = p is log normally distributed.
#
# ![normal%20and%20log-normal.PNG](attachment:normal%20and%20log-normal.PNG)
#
# 4. Prices are frequently assumed to arrive from log normal distribution. This does not necessarily hold true in the real world and real data.

# %% [markdown]
# # Why to use Log-Normal Returns?
#
# These are some generally accepted reasons that quantitative analysts use log returns:
#
# 1. Log returns can be interpreted as continuously compounded returns.
# 2. Log returns are time-additive. The multi-period log return is simply the sum of single period log returns.
# 3. The use of log returns prevents security prices from becoming negative in models of security returns.
# 4. For many purposes, log returns of a security can be reasonably modeled as distributed according to a normal distribution.
# 5. When returns and log returns are small (their absolute values are much less than 1), their values are approximately equal.
# 6. Logarithms can help make an algorithm more numerically stable.
